# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('netflix_titles.csv')
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# Handling missing values

# %%
df['description'] = df['description'].fillna('')
df['director'] = df['director'].fillna('')
df['cast'] = df['cast'].fillna('')
df['listed_in'] = df['listed_in'].fillna('')
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1
# 2                Julien Leclercq
# 3
# 4
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
#                                                 cast  \
# 0
# ...

# %% [markdown]
# Directors with most movies

# %%
director_counts = df['director'].replace('', None).dropna().str.split(', ').explode().value_counts().head(10)
print(director_counts)
# Plot the bar chart
plt.figure(figsize=(10, 5))
colors = plt.get_cmap('tab10', len(director_counts))
director_counts.plot(kind='bar', color=colors(range(len(director_counts))))

# Formatting
plt.xlabel("Director")
plt.ylabel("Number of Movies")
plt.title("Top 10 Directors with Most Movies on Netflix")
plt.xticks(rotation=45)
plt.show()
# Out:
# director
# Rajiv Chilaka          22
# Jan Suter              21
# Raúl Campos            19
# Suhas Kadav            16
# Marcus Raboy           16
# Jay Karas              15
# Cathy Garcia-Molina    13
# Jay Chapman            12
# Youssef Chahine        12
# Martin Scorsese        12
# Name: count, dtype: int64

# %%
movies = df[df['type'] == 'Movie'].copy()  
movies['duration_num'] = movies['duration'].str.extract('(\d+)').astype(float)

plt.figure(figsize=(12, 6))
hist = sns.histplot(data=movies, x='duration_num', bins=50, kde=False, color="red", edgecolor="black")
heights = hist.patches

# Apply gradient color based on the height of each bar
for patch in heights:
    # Normalize the height for color scaling
    height = patch.get_height()
    color = plt.cm.Greens(1 - height / max([patch.get_height() for patch in heights]))  
    patch.set_facecolor(color)
plt.title('Movie Duration Distribution')
plt.xlabel('Duration (minutes)')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# Recommendation Model

# %%
from movie_recommendation import NetflixRecommender

recommender = NetflixRecommender(df)
title = "The Witcher"
recommendations = recommender.get_recommendations(title, n_recommendations=5)
for recommendation in recommendations:
    print(f"Title: {recommendation['title']}, Similarity: {recommendation['similarity_score']}")
# Out:
# [nltk_data] Downloading package stopwords to /Users/jala/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Title: The Witcher: A Look Inside the Episodes, Similarity: 0.4424468947719914
# Title: Making The Witcher, Similarity: 0.3383793861635516
# Title: The Irregulars, Similarity: 0.12916770659862803
# Title: Ripper Street, Similarity: 0.12194207725957915
# Title: Wanderlust, Similarity: 0.1177590166245338
